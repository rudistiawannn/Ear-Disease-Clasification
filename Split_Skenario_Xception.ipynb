# %% [markdown]
# <a href="https://colab.research.google.com/github/rudistiawannn/Ear-Disease-Clasification/blob/main/Split_Skenario_Xception.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scenario 3 with Xception

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D, GlobalAveragePooling2D

# %%
datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1,  # Shift to range [-1, 1]
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode="nearest"
)
validation_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

test_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

# %%
# Training set and validation set
train_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset Skenario/Training/train',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset Skenario/Training/validation',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset Skenario/Testing',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical',
)
# Out:
# Found 715 images belonging to 20 classes.
# Found 181 images belonging to 20 classes.
# Found 227 images belonging to 20 classes.

# %%
# Load the Xception model
pre_trained_model = Xception(input_shape=(229, 229, 3), include_top=False, weights='imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = False

# Define input
input_layer = Input(shape=(229, 229, 3))

# Build the model
x = pre_trained_model(input_layer)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(20, activation='softmax')(x)

# Create the model
model = Model(inputs=input_layer, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 5s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 229, 229, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ xception (Functional)                │ (None, 7, 7, 2048)          │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │           5,140 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,391,164 (81.60 MB)
#  Trainable params: 529,684 (2.02 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
import tensorflow as tf

# Model Compile
OPT = tf.keras.optimizers.Adam(learning_rate=0.0001)
METRIC = tf.keras.metrics.AUC(name='auc')

model.compile(loss='categorical_crossentropy',
              metrics=[METRIC],
              optimizer=OPT)

# %%
filepath = '/content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras'

checkpoint    = ModelCheckpoint(filepath,
                                monitor = 'val_auc',
                                mode='max',
                                save_best_only=True,
                                verbose = 1)


callback_list = [checkpoint]

# %%
model_history=model.fit(train_generator,
                        validation_data=validation_generator,
                        epochs = 100,

                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - auc: 0.5745 - loss: 2.9942
# Epoch 1: val_auc improved from -inf to 0.68037, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 122s 10s/step - auc: 0.5757 - loss: 2.9919 - val_auc: 0.6804 - val_loss: 2.8637
# Epoch 2/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 502ms/step - auc: 0.6358 - loss: 2.8887
# Epoch 2: val_auc improved from 0.68037 to 0.70629, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 790ms/step - auc: 0.6366 - loss: 2.8872 - val_auc: 0.7063 - val_loss: 2.8246
# Epoch 3/100
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 545ms/step - auc: 0.6949 - loss: 2.7720
# Epoch 3: val_auc improved from 0.70629 to 0.73528, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 828ms/step - auc: 0.6959 - loss: 2.7702 - val_auc: 0.7353 - val_loss: 2.7824
# Epoch 4/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 719ms/step - auc: 0.7232 - loss: 2.7043
# Epoch 4: val_auc improved from 0.73528 to 0.76928, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - auc: 0.7239 - loss: 2.7032 - val_auc: 0.7693 - val_loss: 2.7113
# Epoch 5/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 579ms/step - auc: 0.7467 - loss: 2.6312
# Epoch 5: val_auc improved from 0.76928 to 0.78905, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 937ms/step - auc: 0.7466 - loss: 2.6319 - val_auc: 0.7891 - val_loss: 2.6584
# Epoch 6/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 510ms/step - auc: 0.7681 - loss: 2.5862
# Epoch 6: val_auc did not improve from 0.78905
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 745ms/step - auc: 0.7681 - loss: 2.5864 - val_auc: 0.7887 - val_loss: 2.6464
# Epoch 7/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 629ms/step - auc: 0.7901 - loss: 2.5149
# Epoch 7: val_auc improved from 0.78905 to 0.80069, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 966ms/step - auc: 0.7905 - loss: 2.5142 - val_auc: 0.8007 - val_loss: 2.6036
# Epoch 8/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - auc: 0.8100 - loss: 2.4507
# Epoch 8: val_auc improved from 0.80069 to 0.80755, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 983ms/step - auc: 0.8099 - loss: 2.4505 - val_auc: 0.8075 - val_loss: 2.5637
# Epoch 9/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 568ms/step - auc: 0.8143 - loss: 2.4154
# Epoch 9: val_auc improved from 0.80755 to 0.82316, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 931ms/step - auc: 0.8144 - loss: 2.4150 - val_auc: 0.8232 - val_loss: 2.5099
# Epoch 10/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 637ms/step - auc: 0.8260 - loss: 2.3620
# Epoch 10: val_auc improved from 0.82316 to 0.82669, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 912ms/step - auc: 0.8260 - loss: 2.3617 - val_auc: 0.8267 - val_loss: 2.4689
# Epoch 11/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - auc: 0.8410 - loss: 2.2958
# Epoch 11: val_auc improved from 0.82669 to 0.82894, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 804ms/step - auc: 0.8407 - loss: 2.2963 - val_auc: 0.8289 - val_loss: 2.4564
# Epoch 12/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 708ms/step - auc: 0.8399 - loss: 2.3046
# Epoch 12: val_auc did not improve from 0.82894
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 886ms/step - auc: 0.8402 - loss: 2.3016 - val_auc: 0.8287 - val_loss: 2.4409
# Epoch 13/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 689ms/step - auc: 0.8550 - loss: 2.2527
# Epoch 13: val_auc improved from 0.82894 to 0.83769, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 977ms/step - auc: 0.8551 - loss: 2.2504 - val_auc: 0.8377 - val_loss: 2.3880
# Epoch 14/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 577ms/step - auc: 0.8598 - loss: 2.2011
# Epoch 14: val_auc improved from 0.83769 to 0.83946, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 929ms/step - auc: 0.8599 - loss: 2.2004 - val_auc: 0.8395 - val_loss: 2.3745
# Epoch 15/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 634ms/step - auc: 0.8629 - loss: 2.1643
# Epoch 15: val_auc improved from 0.83946 to 0.85257, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 918ms/step - auc: 0.8633 - loss: 2.1616 - val_auc: 0.8526 - val_loss: 2.3166
# Epoch 16/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step - auc: 0.8904 - loss: 2.0303
# Epoch 16: val_auc did not improve from 0.85257
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 727ms/step - auc: 0.8902 - loss: 2.0306 - val_auc: 0.8514 - val_loss: 2.2918
# Epoch 17/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - auc: 0.8882 - loss: 2.0055
# Epoch 17: val_auc improved from 0.85257 to 0.85360, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - auc: 0.8873 - loss: 2.0106 - val_auc: 0.8536 - val_loss: 2.2824
# Epoch 18/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 623ms/step - auc: 0.8815 - loss: 2.0657
# Epoch 18: val_auc improved from 0.85360 to 0.85763, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 40s 911ms/step - auc: 0.8817 - loss: 2.0624 - val_auc: 0.8576 - val_loss: 2.2576
# Epoch 19/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 599ms/step - auc: 0.8833 - loss: 2.0166
# Epoch 19: val_auc improved from 0.85763 to 0.85894, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 972ms/step - auc: 0.8837 - loss: 2.0145 - val_auc: 0.8589 - val_loss: 2.2344
# Epoch 20/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 764ms/step - auc: 0.8932 - loss: 1.9664
# Epoch 20: val_auc improved from 0.85894 to 0.86150, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - auc: 0.8934 - loss: 1.9654 - val_auc: 0.8615 - val_loss: 2.2188
# Epoch 21/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 602ms/step - auc: 0.9062 - loss: 1.8964
# Epoch 21: val_auc improved from 0.86150 to 0.86894, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 970ms/step - auc: 0.9061 - loss: 1.8964 - val_auc: 0.8689 - val_loss: 2.1861
# Epoch 22/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - auc: 0.8983 - loss: 1.9047
# Epoch 22: val_auc did not improve from 0.86894
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 815ms/step - auc: 0.8983 - loss: 1.9047 - val_auc: 0.8667 - val_loss: 2.1714
# Epoch 23/100
# 11/12 ━━━━━━━━━━━━━━━━━━━━ 0s 667ms/step - auc: 0.9052 - loss: 1.8734
# Epoch 23: val_auc improved from 0.86894 to 0.86996, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 895ms/step - auc: 0.9056 - loss: 1.8716 - val_auc: 0.8700 - val_loss: 2.1522
# Epoch 24/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step - auc: 0.9115 - loss: 1.8428
# Epoch 24: val_auc improved from 0.86996 to 0.87446, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 793ms/step - auc: 0.9114 - loss: 1.8417 - val_auc: 0.8745 - val_loss: 2.1311
# Epoch 25/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - auc: 0.9060 - loss: 1.8650
# Epoch 25: val_auc improved from 0.87446 to 0.87586, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - auc: 0.9060 - loss: 1.8636 - val_auc: 0.8759 - val_loss: 2.1075
# Epoch 26/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 606ms/step - auc: 0.9239 - loss: 1.7779
# Epoch 26: val_auc did not improve from 0.87586
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 780ms/step - auc: 0.9235 - loss: 1.7777 - val_auc: 0.8734 - val_loss: 2.1168
# Epoch 27/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - auc: 0.9050 - loss: 1.8359
# Epoch 27: val_auc improved from 0.87586 to 0.87745, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 999ms/step - auc: 0.9056 - loss: 1.8315 - val_auc: 0.8774 - val_loss: 2.0929
# Epoch 28/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step - auc: 0.9238 - loss: 1.7144
# Epoch 28: val_auc improved from 0.87745 to 0.88026, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 775ms/step - auc: 0.9233 - loss: 1.7177 - val_auc: 0.8803 - val_loss: 2.0763
# Epoch 29/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 613ms/step - auc: 0.9166 - loss: 1.7459
# Epoch 29: val_auc did not improve from 0.88026
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 797ms/step - auc: 0.9167 - loss: 1.7442 - val_auc: 0.8786 - val_loss: 2.0804
# Epoch 30/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - auc: 0.9136 - loss: 1.7525
# Epoch 30: val_auc did not improve from 0.88026
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 900ms/step - auc: 0.9143 - loss: 1.7492 - val_auc: 0.8772 - val_loss: 2.0768
# Epoch 31/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step - auc: 0.9332 - loss: 1.6489
# Epoch 31: val_auc did not improve from 0.88026
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 718ms/step - auc: 0.9331 - loss: 1.6475 - val_auc: 0.8799 - val_loss: 2.0507
# Epoch 32/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - auc: 0.9263 - loss: 1.6585
# Epoch 32: val_auc improved from 0.88026 to 0.88262, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 971ms/step - auc: 0.9266 - loss: 1.6570 - val_auc: 0.8826 - val_loss: 2.0325
# Epoch 33/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 581ms/step - auc: 0.9297 - loss: 1.6274
# Epoch 33: val_auc improved from 0.88262 to 0.88553, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 866ms/step - auc: 0.9294 - loss: 1.6294 - val_auc: 0.8855 - val_loss: 2.0233
# Epoch 34/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - auc: 0.9274 - loss: 1.6518
# Epoch 34: val_auc improved from 0.88553 to 0.88641, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 880ms/step - auc: 0.9274 - loss: 1.6510 - val_auc: 0.8864 - val_loss: 2.0115
# Epoch 35/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - auc: 0.9365 - loss: 1.5685
# Epoch 35: val_auc improved from 0.88641 to 0.88758, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 956ms/step - auc: 0.9365 - loss: 1.5689 - val_auc: 0.8876 - val_loss: 1.9928
# Epoch 36/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 701ms/step - auc: 0.9271 - loss: 1.6378
# Epoch 36: val_auc did not improve from 0.88758
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 873ms/step - auc: 0.9278 - loss: 1.6323 - val_auc: 0.8855 - val_loss: 2.0054
# Epoch 37/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 678ms/step - auc: 0.9407 - loss: 1.5370
# Epoch 37: val_auc improved from 0.88758 to 0.88952, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 796ms/step - auc: 0.9591 - loss: 1.3037 - val_auc: 0.8980 - val_loss: 1.8867
# Epoch 53/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - auc: 0.9543 - loss: 1.3643
# Epoch 53: val_auc did not improve from 0.89847
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 848ms/step - auc: 0.9543 - loss: 1.3640 - val_auc: 0.8978 - val_loss: 1.8862
# Epoch 54/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 749ms/step - auc: 0.9580 - loss: 1.3386
# Epoch 54: val_auc improved from 0.89847 to 0.89943, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - auc: 0.9578 - loss: 1.3387 - val_auc: 0.8994 - val_loss: 1.8695
# Epoch 55/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 610ms/step - auc: 0.9603 - loss: 1.3038
# Epoch 55: val_auc improved from 0.89943 to 0.90093, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 926ms/step - auc: 0.9603 - loss: 1.3033 - val_auc: 0.9009 - val_loss: 1.8644
# Epoch 56/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 506ms/step - auc: 0.9585 - loss: 1.3186
# Epoch 56: val_auc did not improve from 0.90093
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 39s 739ms/step - auc: 0.9588 - loss: 1.3162 - val_auc: 0.8988 - val_loss: 1.8659
# Epoch 57/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - auc: 0.9561 - loss: 1.3064
# Epoch 57: val_auc did not improve from 0.90093
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 852ms/step - auc: 0.9563 - loss: 1.3060 - val_auc: 0.9005 - val_loss: 1.8642
# Epoch 58/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 505ms/step - auc: 0.9560 - loss: 1.3395
# Epoch 58: val_auc improved from 0.90093 to 0.90309, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 799ms/step - auc: 0.9563 - loss: 1.3356 - val_auc: 0.9031 - val_loss: 1.8463
# Epoch 59/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 769ms/step - auc: 0.9629 - loss: 1.2894
# Epoch 59: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 946ms/step - auc: 0.9628 - loss: 1.2886 - val_auc: 0.8984 - val_loss: 1.8736
# Epoch 60/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 645ms/step - auc: 0.9690 - loss: 1.1765
# Epoch 60: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 826ms/step - auc: 0.9686 - loss: 1.1813 - val_auc: 0.8989 - val_loss: 1.8640
# Epoch 61/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 652ms/step - auc: 0.9539 - loss: 1.3262
# Epoch 61: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 848ms/step - auc: 0.9543 - loss: 1.3225 - val_auc: 0.9027 - val_loss: 1.8405
# Epoch 62/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 725ms/step - auc: 0.9635 - loss: 1.2304
# Epoch 62: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 903ms/step - auc: 0.9632 - loss: 1.2330 - val_auc: 0.8982 - val_loss: 1.8749
# Epoch 63/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 508ms/step - auc: 0.9614 - loss: 1.2415
# Epoch 63: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 704ms/step - auc: 0.9616 - loss: 1.2405 - val_auc: 0.8972 - val_loss: 1.8713
# Epoch 64/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 743ms/step - auc: 0.9653 - loss: 1.1941
# Epoch 64: val_auc did not improve from 0.90309
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 917ms/step - auc: 0.9652 - loss: 1.1977 - val_auc: 0.9022 - val_loss: 1.8388
# Epoch 65/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 585ms/step - auc: 0.9642 - loss: 1.2345
# Epoch 65: val_auc improved from 0.90309 to 0.90355, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 22s 903ms/step - auc: 0.9643 - loss: 1.2324 - val_auc: 0.9035 - val_loss: 1.8353
# Epoch 66/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 758ms/step - auc: 0.9659 - loss: 1.2115
# Epoch 66: val_auc improved from 0.90355 to 0.90641, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - auc: 0.9656 - loss: 1.2124 - val_auc: 0.9064 - val_loss: 1.8104
# Epoch 67/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 604ms/step - auc: 0.9619 - loss: 1.2417
# Epoch 67: val_auc did not improve from 0.90641
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s
# Epoch 83/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - auc: 0.9727 - loss: 1.0937
# Epoch 83: val_auc did not improve from 0.91029
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 768ms/step - auc: 0.9727 - loss: 1.0940 - val_auc: 0.9090 - val_loss: 1.7789
# Epoch 84/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 647ms/step - auc: 0.9718 - loss: 1.0937
# Epoch 84: val_auc did not improve from 0.91029
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 823ms/step - auc: 0.9717 - loss: 1.0942 - val_auc: 0.9083 - val_loss: 1.7791
# Epoch 85/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - auc: 0.9733 - loss: 1.0786
# Epoch 85: val_auc did not improve from 0.91029
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 838ms/step - auc: 0.9735 - loss: 1.0763 - val_auc: 0.9069 - val_loss: 1.7870
# Epoch 86/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 684ms/step - auc: 0.9740 - loss: 1.0673
# Epoch 86: val_auc improved from 0.91029 to 0.91330, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 969ms/step - auc: 0.9742 - loss: 1.0653 - val_auc: 0.9133 - val_loss: 1.7481
# Epoch 87/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - auc: 0.9727 - loss: 1.0885
# Epoch 87: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 836ms/step - auc: 0.9727 - loss: 1.0878 - val_auc: 0.9110 - val_loss: 1.7565
# Epoch 88/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 661ms/step - auc: 0.9763 - loss: 0.9993
# Epoch 88: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 857ms/step - auc: 0.9763 - loss: 1.0020 - val_auc: 0.9113 - val_loss: 1.7604
# Epoch 89/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 614ms/step - auc: 0.9768 - loss: 1.0261
# Epoch 89: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 785ms/step - auc: 0.9769 - loss: 1.0252 - val_auc: 0.9112 - val_loss: 1.7623
# Epoch 90/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 620ms/step - auc: 0.9763 - loss: 1.0296
# Epoch 90: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 853ms/step - auc: 0.9761 - loss: 1.0306 - val_auc: 0.9101 - val_loss: 1.7691
# Epoch 91/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 662ms/step - auc: 0.9756 - loss: 1.0561
# Epoch 91: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 836ms/step - auc: 0.9755 - loss: 1.0572 - val_auc: 0.9118 - val_loss: 1.7606
# Epoch 92/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 626ms/step - auc: 0.9763 - loss: 0.9958
# Epoch 92: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 806ms/step - auc: 0.9764 - loss: 0.9956 - val_auc: 0.9108 - val_loss: 1.7595
# Epoch 93/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - auc: 0.9780 - loss: 1.0280
# Epoch 93: val_auc did not improve from 0.91330
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 832ms/step - auc: 0.9781 - loss: 1.0262 - val_auc: 0.9106 - val_loss: 1.7560
# Epoch 94/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - auc: 0.9788 - loss: 0.9948
# Epoch 94: val_auc improved from 0.91330 to 0.91368, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 1s/step - auc: 0.9789 - loss: 0.9937 - val_auc: 0.9137 - val_loss: 1.7417
# Epoch 95/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 516ms/step - auc: 0.9790 - loss: 0.9836
# Epoch 95: val_auc did not improve from 0.91368
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 742ms/step - auc: 0.9789 - loss: 0.9848 - val_auc: 0.9134 - val_loss: 1.7438
# Epoch 96/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 665ms/step - auc: 0.9771 - loss: 0.9944
# Epoch 96: val_auc did not improve from 0.91368
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 841ms/step - auc: 0.9772 - loss: 0.9949 - val_auc: 0.9130 - val_loss: 1.7389
# Epoch 97/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 513ms/step - auc: 0.9811 - loss: 0.9605
# Epoch 97: val_auc did not improve from 0.91368
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 18s 687ms/step - auc: 0.9810 - loss: 0.9613 - val_auc: 0.9106 - val_loss: 1.7629
# Epoch 98/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 632ms/step - auc: 0.9749 - loss: 1.0332
# Epoch 98: val_auc did not improve from 0.91368
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 19s 855ms/step - auc: 0.9749 - loss: 1.0328 - val_auc: 0.9118 - val_loss: 1.7540
# Epoch 99/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 580ms/step - auc: 0.9791 - loss: 0.9629
# Epoch 99: val_auc did not improve from 0.91368
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 20s 754ms/step - auc: 0.9792 - loss: 0.9623 - val_auc: 0.9103 - val_loss: 1.7460
# Epoch 100/100
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 615ms/step - auc: 0.9821 - loss: 0.9225
# Epoch 100: val_auc improved from 0.91368 to 0.91393, saving model to /content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 21s 963ms/step - auc: 0.9820 - loss: 0.9253 - val_auc: 0.9139 - val_loss: 1.7290

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(model_history.history[met])
    ax[i].plot(model_history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
model.evaluate(test_generator)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 91s 30s/step - auc: 0.8945 - loss: 1.8508
# [1.8512111902236938, 0.8925597667694092]

# %%
from tensorflow.keras.models import load_model
# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step

# %%
from sklearn.metrics import roc_auc_score

# Compute AUC
auc = roc_auc_score(y_true, y_pred, multi_class='ovo')
print(f'AUC on the test set: {auc}')
# Out:
# AUC on the test set: 0.5397103901153166

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal', 'Miringitis Bulosa', 'Normal', 'OE Difusa', 'OE Furunkulosa',
    'OMA Hiperemis', 'OMA Oklusi Tuba', 'OMA Perforasi', 'OMA Resolusi', 'OMA Supurasi', 'OM Efusi', 'OMSK Resolusi', 'OMSK Tipe Aman',
    'OMSK Tipe Bahaya', 'Otomikosis', 'Perforasi M T', 'Tympanosklerotik'
]

# Plot the confusion matrix using seaborn for better visualization
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 997ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_Skenario_2.keras')

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal',
    'Miringitis Bulosa', 'Normal', 'Otomikosis', 'OE Difusa',
    'OE Furunkulosa', 'OMA Hiperemis',
    'OMA Oklusi Tuba', 'OMA Perforasi',
    'OMA Resolusi', 'OMA Supurasi',
    'OM Efusi', 'OMSK Resolusi',
    'OMSK Tipe Aman', 'OMSK Tipe Bahaya',
    'Perforasi M T', 'Tympanosklerotik'
]

def load_and_preprocess_image(img_path, target_size=(224, 224)):
    # Load the image
    img = image.load_img(img_path, target_size=target_size)
    # Convert the image to array
    img_array = image.img_to_array(img)
    # Expand dimensions to match the model input
    img_array = np.expand_dims(img_array, axis=0)
    # Normalize the image
    img_array = img_array / 255.0
    return img_array

def predict_image(img_path):
    # Preprocess the image
    img_array = load_and_preprocess_image(img_path)
    # Make prediction
    predictions = model.predict(img_array)
    # Get the class with highest probability
    predicted_class = np.argmax(predictions, axis=1)
    # Get the class name
    predicted_class_name = class_names[predicted_class[0]]

    # Plot the image with prediction
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.title(f'Predicted: {predicted_class_name}')
    plt.axis('off')
    plt.show()

    return predicted_class_name

# Test the function with an image path
img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
predicted_class_name = predict_image(img_path)
print(f'The model predicts: {predicted_class_name}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d37865027173> in <cell line: 53>()
#      51 # Test the function with an image path
#      52 img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
# ---> 53 predicted_class_name = predict_image(img_path)
#      54 print(f'The model predicts: {predicted_class_name}')
#
# <ipython-input-16-d37865027173> in predict_image(img_path)
#      34     img_array = load_and_preprocess_image(img_path)
#      35     # Make prediction
# ---> 36     predictions = model.predict(img_array)
#      37     # Get the class with highest probability
#      38     predicted_class = np.argmax(predictions, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
#     244                     if spec_dim != dim:
# --> 245                         raise ValueError(
#     246                             f'Input {input_index} of layer "{layer_name}" is '
#     247                             "incompatible with the layer: "
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 229, 229, 3), found shape=(1, 224, 224, 3)
