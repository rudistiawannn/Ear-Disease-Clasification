# %% [markdown]
# <a href="https://colab.research.google.com/github/rudistiawannn/Ear-Disease-Clasification/blob/main/Fix_1_Xception_EarDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scenario 1 with Xception

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D, GlobalAveragePooling2D

# %%
datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1,  # Shift to range [-1, 1]
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode="nearest"
)
validation_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

test_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

# %%
# Training set and validation set
train_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/train',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/validation',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/test',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical',
)
# Out:
# Found 836 images belonging to 20 classes.
# Found 214 images belonging to 20 classes.
# Found 233 images belonging to 20 classes.

# %%
# Load the Xception model
pre_trained_model = Xception(input_shape=(229, 229, 3), include_top=False, weights='imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = False

# Define input
input_layer = Input(shape=(229, 229, 3))

# Build the model
x = pre_trained_model(input_layer)
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(20, activation='softmax')(x)

# Create the model
model = Model(inputs=input_layer, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 229, 229, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ xception (Functional)                │ (None, 7, 7, 2048)          │      20,861,480 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 2048)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │         524,544 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 20)                  │           5,140 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 21,391,164 (81.60 MB)
#  Trainable params: 529,684 (2.02 MB)
#  Non-trainable params: 20,861,480 (79.58 MB)

# %%
import tensorflow as tf

# Model Compile
OPT = tf.keras.optimizers.Adam(learning_rate=0.0001)
METRIC = tf.keras.metrics.AUC(name='auc')

model.compile(loss='categorical_crossentropy',
              metrics=[METRIC],
              optimizer=OPT)

# %%
filepath = '/content/drive/MyDrive/Ear Disease/Xception_1.keras'

checkpoint    = ModelCheckpoint(filepath,
                                monitor = 'val_auc',
                                mode='max',
                                save_best_only=True,
                                verbose = 1)


callback_list = [checkpoint]

# %%
model_history=model.fit(train_generator,
                        validation_data=validation_generator,
                        epochs = 100,

                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - auc: 0.5049 - loss: 3.2234
# Epoch 1: val_auc improved from -inf to 0.59841, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 409s 17s/step - auc: 0.5051 - loss: 3.2199 - val_auc: 0.5984 - val_loss: 2.9419
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 740ms/step - auc: 0.5682 - loss: 2.9919
# Epoch 2: val_auc improved from 0.59841 to 0.65238, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 59s 1s/step - auc: 0.5696 - loss: 2.9895 - val_auc: 0.6524 - val_loss: 2.8834
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 791ms/step - auc: 0.6557 - loss: 2.8439
# Epoch 3: val_auc improved from 0.65238 to 0.70013, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - auc: 0.6560 - loss: 2.8434 - val_auc: 0.7001 - val_loss: 2.8178
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - auc: 0.6805 - loss: 2.7929
# Epoch 4: val_auc improved from 0.70013 to 0.72296, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 975ms/step - auc: 0.6813 - loss: 2.7916 - val_auc: 0.7230 - val_loss: 2.7794
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 590ms/step - auc: 0.7131 - loss: 2.7258
# Epoch 5: val_auc improved from 0.72296 to 0.76300, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - auc: 0.7137 - loss: 2.7245 - val_auc: 0.7630 - val_loss: 2.7027
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - auc: 0.7338 - loss: 2.6743
# Epoch 6: val_auc improved from 0.76300 to 0.79692, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - auc: 0.7344 - loss: 2.6725 - val_auc: 0.7969 - val_loss: 2.6136
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - auc: 0.7817 - loss: 2.5389
# Epoch 7: val_auc did not improve from 0.79692
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 1s/step - auc: 0.7812 - loss: 2.5406 - val_auc: 0.7857 - val_loss: 2.6209
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 591ms/step - auc: 0.8056 - loss: 2.4845
# Epoch 8: val_auc improved from 0.79692 to 0.80805, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 890ms/step - auc: 0.8052 - loss: 2.4850 - val_auc: 0.8081 - val_loss: 2.5640
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 805ms/step - auc: 0.8105 - loss: 2.4627
# Epoch 9: val_auc did not improve from 0.80805
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 970ms/step - auc: 0.8107 - loss: 2.4615 - val_auc: 0.8068 - val_loss: 2.5353
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 660ms/step - auc: 0.8298 - loss: 2.3771
# Epoch 10: val_auc improved from 0.80805 to 0.81725, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 977ms/step - auc: 0.8295 - loss: 2.3780 - val_auc: 0.8173 - val_loss: 2.4976
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - auc: 0.8416 - loss: 2.3246
# Epoch 11: val_auc improved from 0.81725 to 0.82942, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 995ms/step - auc: 0.8413 - loss: 2.3250 - val_auc: 0.8294 - val_loss: 2.4445
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 794ms/step - auc: 0.8475 - loss: 2.2460
# Epoch 12: val_auc improved from 0.82942 to 0.84284, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - auc: 0.8465 - loss: 2.2501 - val_auc: 0.8428 - val_loss: 2.4067
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 688ms/step - auc: 0.8557 - loss: 2.2291
# Epoch 13: val_auc improved from 0.84284 to 0.85057, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 992ms/step - auc: 0.8555 - loss: 2.2296 - val_auc: 0.8506 - val_loss: 2.3618
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 660ms/step - auc: 0.8715 - loss: 2.1523
# Epoch 14: val_auc improved from 0.85057 to 0.85293, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - auc: 0.8711 - loss: 2.1537 - val_auc: 0.8529 - val_loss: 2.3239
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 674ms/step - auc: 0.8671 - loss: 2.1299
# Epoch 15: val_auc improved from 0.85293 to 0.86862, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 1s/step - auc: 0.8665 - loss: 2.1326 - val_auc: 0.8686 - val_loss: 2.2721
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 679ms/step - auc: 0.8642 - loss: 2.1457
# Epoch 16: val_auc did not improve from 0.86862
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 887ms/step - auc: 0.8645 - loss: 2.1440 - val_auc: 0.8672 - val_loss: 2.2621
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 605ms/step - auc: 0.8867 - loss: 2.0406
# Epoch 17: val_auc did not improve from 0.86862
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 818ms/step - auc: 0.8859 - loss: 2.0437 - val_auc: 0.8619 - val_loss: 2.2400
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 619ms/step - auc: 0.8662 - loss: 2.1239
# Epoch 18: val_auc did not improve from 0.86862
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 800ms/step - auc: 0.8667 - loss: 2.1217 - val_auc: 0.8610 - val_loss: 2.2422
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 770ms/step - auc: 0.8839 - loss: 2.0351
# Epoch 19: val_auc did not improve from 0.86862
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 932ms/step - auc: 0.8835 - loss: 2.0364 - val_auc: 0.8671 - val_loss: 2.2203
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 729ms/step - auc: 0.8858 - loss: 2.0341
# Epoch 20: val_auc improved from 0.86862 to 0.87064, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - auc: 0.8862 - loss: 2.0315 - val_auc: 0.8706 - val_loss: 2.2015
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - auc: 0.8867 - loss: 1.9859
# Epoch 21: val_auc improved from 0.87064 to 0.87928, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - auc: 0.8868 - loss: 1.9855 - val_auc: 0.8793 - val_loss: 2.1464
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 779ms/step - auc: 0.8830 - loss: 1.9823
# Epoch 22: val_auc did not improve from 0.87928
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 943ms/step - auc: 0.8832 - loss: 1.9821 - val_auc: 0.8737 - val_loss: 2.1357
# Epoch 23/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 771ms/step - auc: 0.8985 - loss: 1.9099
# Epoch 23: val_auc improved from 0.87928 to 0.88309, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 981ms/step - auc: 0.8990 - loss: 1.9079 - val_auc: 0.8831 - val_loss: 2.1015
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 681ms/step - auc: 0.9038 - loss: 1.8627
# Epoch 24: val_auc did not improve from 0.88309
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 845ms/step - auc: 0.9041 - loss: 1.8617 - val_auc: 0.8770 - val_loss: 2.1234
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - auc: 0.9104 - loss: 1.8294
# Epoch 25: val_auc did not improve from 0.88309
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 880ms/step - auc: 0.9102 - loss: 1.8300 - val_auc: 0.8791 - val_loss: 2.1124
# Epoch 26/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 592ms/step - auc: 0.9133 - loss: 1.8144
# Epoch 26: val_auc did not improve from 0.88309
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 987ms/step - auc: 0.9133 - loss: 1.8140 - val_auc: 0.8813 - val_loss: 2.0663
# Epoch 27/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 720ms/step - auc: 0.9171 - loss: 1.7814
# Epoch 27: val_auc improved from 0.88309 to 0.88867, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 930ms/step - auc: 0.9169 - loss: 1.7830 - val_auc: 0.8887 - val_loss: 2.0463
# Epoch 28/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 694ms/step - auc: 0.9118 - loss: 1.7867
# Epoch 28: val_auc did not improve from 0.88867
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 862ms/step - auc: 0.9115 - loss: 1.7885 - val_auc: 0.8875 - val_loss: 2.0465
# Epoch 29/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 722ms/step - auc: 0.9266 - loss: 1.6831
# Epoch 29: val_auc improved from 0.88867 to 0.89230, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - auc: 0.9261 - loss: 1.6876 - val_auc: 0.8923 - val_loss: 2.0211
# Epoch 30/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 601ms/step - auc: 0.9170 - loss: 1.7487
# Epoch 30: val_auc improved from 0.89230 to 0.89356, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 891ms/step - auc: 0.9173 - loss: 1.7473 - val_auc: 0.8936 - val_loss: 1.9982
# Epoch 31/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 734ms/step - auc: 0.9117 - loss: 1.7822
# Epoch 31: val_auc did not improve from 0.89356
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 900ms/step - auc: 0.9120 - loss: 1.7793 - val_auc: 0.8904 - val_loss: 2.0170
# Epoch 32/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 704ms/step - auc: 0.9291 - loss: 1.6997
# Epoch 32: val_auc did not improve from 0.89356
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 869ms/step - auc: 0.9290 - loss: 1.6987 - val_auc: 0.8922 - val_loss: 1.9956
# Epoch 33/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 774ms/step - auc: 0.9292 - loss: 1.6769
# Epoch 33: val_auc improved from 0.89356 to 0.89467, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 974ms/step - auc: 0.9288 - loss: 1.6795 - val_auc: 0.8947 - val_loss: 1.9815
# Epoch 34/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 598ms/step - auc: 0.9165 - loss: 1.7391
# Epoch 34: val_auc improved from 0.89467 to 0.89720, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 884ms/step - auc: 0.9168 - loss: 1.7368 - val_auc: 0.8972 - val_loss: 1.9696
# Epoch 35/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 642ms/step - auc: 0.9240 - loss: 1.7071
# Epoch 35: val_auc did not improve from 0.89720
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 807ms/step - auc: 0.9242 - loss: 1.7042 - val_auc: 0.8971 - val_loss: 1.9774
# Epoch 36/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 785ms/step - auc: 0.9309 - loss: 1.6014
# Epoch 36: val_auc did not improve from 0.89720
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 956ms/step - auc: 0.9308 - loss: 1.6024 - val_auc: 0.8964 - val_loss: 1.9607
# Epoch 37/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 693ms/step - auc: 0.9309 - loss: 1.6092
# Epoch 37: val_auc improved from 0.89720 to 0.89859, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - auc: 0.9308 - loss: 1.6098 - val_auc: 0.8986 - val_loss: 1.9468
# Epoch 38/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s

# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 965ms/step - auc: 0.9510 - loss: 1.4006 - val_auc: 0.9073 - val_loss: 1.8552
# Epoch 54/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - auc: 0.9528 - loss: 1.3863
# Epoch 54: val_auc improved from 0.91264 to 0.91510, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 975ms/step - auc: 0.9528 - loss: 1.3870 - val_auc: 0.9151 - val_loss: 1.8071
# Epoch 55/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 761ms/step - auc: 0.9537 - loss: 1.3704
# Epoch 55: val_auc improved from 0.91510 to 0.91515, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 959ms/step - auc: 0.9535 - loss: 1.3719 - val_auc: 0.9152 - val_loss: 1.8009
# Epoch 56/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 798ms/step - auc: 0.9543 - loss: 1.3536
# Epoch 56: val_auc did not improve from 0.91515
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 39s 977ms/step - auc: 0.9545 - loss: 1.3516 - val_auc: 0.9096 - val_loss: 1.8346
# Epoch 57/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 819ms/step - auc: 0.9606 - loss: 1.2838
# Epoch 57: val_auc did not improve from 0.91515
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 994ms/step - auc: 0.9603 - loss: 1.2868 - val_auc: 0.9136 - val_loss: 1.7913
# Epoch 58/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 754ms/step - auc: 0.9539 - loss: 1.3557
# Epoch 58: val_auc did not improve from 0.91515
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 936ms/step - auc: 0.9540 - loss: 1.3544 - val_auc: 0.9140 - val_loss: 1.7925
# Epoch 59/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 695ms/step - auc: 0.9613 - loss: 1.2506
# Epoch 59: val_auc improved from 0.91515 to 0.91527, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 43s 1s/step - auc: 0.9609 - loss: 1.2552 - val_auc: 0.9153 - val_loss: 1.7910
# Epoch 60/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 829ms/step - auc: 0.9624 - loss: 1.2833
# Epoch 60: val_auc improved from 0.91527 to 0.91617, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - auc: 0.9623 - loss: 1.2837 - val_auc: 0.9162 - val_loss: 1.7831
# Epoch 61/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 603ms/step - auc: 0.9571 - loss: 1.3276
# Epoch 61: val_auc improved from 0.91617 to 0.91637, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 918ms/step - auc: 0.9569 - loss: 1.3293 - val_auc: 0.9164 - val_loss: 1.7779
# Epoch 62/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 633ms/step - auc: 0.9628 - loss: 1.2281
# Epoch 62: val_auc did not improve from 0.91637
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 869ms/step - auc: 0.9626 - loss: 1.2309 - val_auc: 0.9127 - val_loss: 1.8030
# Epoch 63/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 726ms/step - auc: 0.9619 - loss: 1.2756
# Epoch 63: val_auc did not improve from 0.91637
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 22s 898ms/step - auc: 0.9617 - loss: 1.2782 - val_auc: 0.9163 - val_loss: 1.7613
# Epoch 64/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 655ms/step - auc: 0.9633 - loss: 1.2741
# Epoch 64: val_auc improved from 0.91637 to 0.91703, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 902ms/step - auc: 0.9632 - loss: 1.2708 - val_auc: 0.9170 - val_loss: 1.7615
# Epoch 65/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 622ms/step - auc: 0.9543 - loss: 1.3449
# Epoch 65: val_auc did not improve from 0.91703
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 852ms/step - auc: 0.9545 - loss: 1.3418 - val_auc: 0.9120 - val_loss: 1.7950
# Epoch 66/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 800ms/step - auc: 0.9534 - loss: 1.3239
# Epoch 66: val_auc did not improve from 0.91703
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - auc: 0.9538 - loss: 1.3203 - val_auc: 0.9134 - val_loss: 1.7898
# Epoch 67/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc: 0.9592 - loss: 1.2650
# Epoch 67: val_auc did not improve from 0.91703
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - auc: 0.9591 - loss: 1.2672 - val_auc: 0.9149 - val_loss: 1.7787
# Epoch 68/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - auc: 0.9661 - loss: 1.2038
# Epoch 68: val_auc improved from 0.91703 to 0.91840, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 1s/step
# Epoch 83/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - auc: 0.9688 - loss: 1.1622
# Epoch 83: val_auc did not improve from 0.92048
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 42s 965ms/step - auc: 0.9689 - loss: 1.1616 - val_auc: 0.9194 - val_loss: 1.7304
# Epoch 84/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - auc: 0.9642 - loss: 1.2153
# Epoch 84: val_auc did not improve from 0.92048
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 881ms/step - auc: 0.9645 - loss: 1.2119 - val_auc: 0.9165 - val_loss: 1.7458
# Epoch 85/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 680ms/step - auc: 0.9648 - loss: 1.1970
# Epoch 85: val_auc did not improve from 0.92048
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 24s 1s/step - auc: 0.9650 - loss: 1.1939 - val_auc: 0.9173 - val_loss: 1.7375
# Epoch 86/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - auc: 0.9726 - loss: 1.1177
# Epoch 86: val_auc improved from 0.92048 to 0.92307, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 974ms/step - auc: 0.9726 - loss: 1.1168 - val_auc: 0.9231 - val_loss: 1.6924
# Epoch 87/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 649ms/step - auc: 0.9670 - loss: 1.1589
# Epoch 87: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 847ms/step - auc: 0.9672 - loss: 1.1566 - val_auc: 0.9193 - val_loss: 1.7158
# Epoch 88/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 790ms/step - auc: 0.9714 - loss: 1.1258
# Epoch 88: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 41s 953ms/step - auc: 0.9715 - loss: 1.1240 - val_auc: 0.9174 - val_loss: 1.7363
# Epoch 89/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - auc: 0.9715 - loss: 1.1194
# Epoch 89: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 864ms/step - auc: 0.9715 - loss: 1.1180 - val_auc: 0.9203 - val_loss: 1.7024
# Epoch 90/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - auc: 0.9714 - loss: 1.0812
# Epoch 90: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 975ms/step - auc: 0.9713 - loss: 1.0832 - val_auc: 0.9225 - val_loss: 1.6950
# Epoch 91/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 714ms/step - auc: 0.9762 - loss: 1.0305
# Epoch 91: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 903ms/step - auc: 0.9760 - loss: 1.0342 - val_auc: 0.9213 - val_loss: 1.7051
# Epoch 92/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 672ms/step - auc: 0.9765 - loss: 1.0349
# Epoch 92: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 840ms/step - auc: 0.9763 - loss: 1.0371 - val_auc: 0.9230 - val_loss: 1.6769
# Epoch 93/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 687ms/step - auc: 0.9735 - loss: 1.0709
# Epoch 93: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 808ms/step - auc: 0.9739 - loss: 1.0664 - val_auc: 0.9230 - val_loss: 1.6835
# Epoch 94/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 806ms/step - auc: 0.9645 - loss: 1.1409
# Epoch 94: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 970ms/step - auc: 0.9650 - loss: 1.1391 - val_auc: 0.9226 - val_loss: 1.7070
# Epoch 95/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 690ms/step - auc: 0.9708 - loss: 1.1179
# Epoch 95: val_auc did not improve from 0.92307
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - auc: 0.9709 - loss: 1.1171 - val_auc: 0.9206 - val_loss: 1.7102
# Epoch 96/100
# 13/14 ━━━━━━━━━━━━━━━━━━━━ 0s 733ms/step - auc: 0.9750 - loss: 1.0535
# Epoch 96: val_auc improved from 0.92307 to 0.92408, saving model to /content/drive/MyDrive/Ear Disease/Xception_1.keras
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 40s 992ms/step - auc: 0.9753 - loss: 1.0501 - val_auc: 0.9241 - val_loss: 1.6762
# Epoch 97/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 815ms/step - auc: 0.9729 - loss: 1.0980
# Epoch 97: val_auc did not improve from 0.92408
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 980ms/step - auc: 0.9730 - loss: 1.0957 - val_auc: 0.9174 - val_loss: 1.7278
# Epoch 98/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 724ms/step - auc: 0.9694 - loss: 1.1101
# Epoch 98: val_auc did not improve from 0.92408
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 889ms/step - auc: 0.9697 - loss: 1.1070 - val_auc: 0.9204 - val_loss: 1.7117
# Epoch 99/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 638ms/step - auc: 0.9788 - loss: 1.0173
# Epoch 99: val_auc did not improve from 0.92408
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 21s 808ms/step - auc: 0.9787 - loss: 1.0175 - val_auc: 0.9205 - val_loss: 1.7065
# Epoch 100/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 677ms/step - auc: 0.9803 - loss: 0.9605
# Epoch 100: val_auc did not improve from 0.92408
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - auc: 0.9799 - loss: 0.9657 - val_auc: 0.9196 - val_loss: 1.7038

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(model_history.history[met])
    ax[i].plot(model_history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
model.evaluate(test_generator)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 54s 18s/step - auc: 0.8896 - loss: 1.8914
# [1.8860441446304321, 0.8887906074523926]

# %%
from tensorflow.keras.models import load_model
# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_1.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 1s/step

# %%
from sklearn.metrics import roc_auc_score

# Compute AUC
auc = roc_auc_score(y_true, y_pred, multi_class='ovo')
print(f'AUC on the test set: {auc}')
# Out:
# AUC on the test set: 0.4787011375944424

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_1.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal', 'Miringitis Bulosa', 'Normal', 'OE Difusa', 'OE Furunkulosa',
    'OMA Hiperemis', 'OMA Oklusi Tuba', 'OMA Perforasi', 'OMA Resolusi', 'OMA Supurasi', 'OM Efusi', 'OMSK Resolusi', 'OMSK Tipe Aman',
    'OMSK Tipe Bahaya', 'Otomikosis', 'Perforasi M T', 'Tympanosklerotik'
]

# Plot the confusion matrix using seaborn for better visualization
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 7s 996ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/Xception_1.keras')

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal',
    'Miringitis Bulosa', 'Normal', 'Otomikosis', 'OE Difusa',
    'OE Furunkulosa', 'OMA Hiperemis',
    'OMA Oklusi Tuba', 'OMA Perforasi',
    'OMA Resolusi', 'OMA Supurasi',
    'OM Efusi', 'OMSK Resolusi',
    'OMSK Tipe Aman', 'OMSK Tipe Bahaya',
    'Perforasi M T', 'Tympanosklerotik'
]

def load_and_preprocess_image(img_path, target_size=(224, 224)):
    # Load the image
    img = image.load_img(img_path, target_size=target_size)
    # Convert the image to array
    img_array = image.img_to_array(img)
    # Expand dimensions to match the model input
    img_array = np.expand_dims(img_array, axis=0)
    # Normalize the image
    img_array = img_array / 255.0
    return img_array

def predict_image(img_path):
    # Preprocess the image
    img_array = load_and_preprocess_image(img_path)
    # Make prediction
    predictions = model.predict(img_array)
    # Get the class with highest probability
    predicted_class = np.argmax(predictions, axis=1)
    # Get the class name
    predicted_class_name = class_names[predicted_class[0]]

    # Plot the image with prediction
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.title(f'Predicted: {predicted_class_name}')
    plt.axis('off')
    plt.show()

    return predicted_class_name

# Test the function with an image path
img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
predicted_class_name = predict_image(img_path)
print(f'The model predicts: {predicted_class_name}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d37865027173> in <cell line: 53>()
#      51 # Test the function with an image path
#      52 img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
# ---> 53 predicted_class_name = predict_image(img_path)
#      54 print(f'The model predicts: {predicted_class_name}')
#
# <ipython-input-16-d37865027173> in predict_image(img_path)
#      34     img_array = load_and_preprocess_image(img_path)
#      35     # Make prediction
# ---> 36     predictions = model.predict(img_array)
#      37     # Get the class with highest probability
#      38     predicted_class = np.argmax(predictions, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
#     244                     if spec_dim != dim:
# --> 245                         raise ValueError(
#     246                             f'Input {input_index} of layer "{layer_name}" is '
#     247                             "incompatible with the layer: "
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 229, 229, 3), found shape=(1, 224, 224, 3)
