# %% [markdown]
# <a href="https://colab.research.google.com/github/rudistiawannn/Ear-Disease-Clasification/blob/main/Fix_2_Xception_EarDisease.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scenario 2 with Xception

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os
import random
import shutil

import numpy as np
import matplotlib.pyplot as plt

from PIL import Image
import tensorflow as tf
from tensorflow.keras import layers, Model, Sequential
from tensorflow.keras.applications import Xception
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, LearningRateScheduler, ModelCheckpoint
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import Input, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPooling2D, Conv2D, GlobalAveragePooling2D

# %%
datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1,  # Shift to range [-1, 1]
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode="nearest"
)
validation_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

test_datagen = ImageDataGenerator(
    rescale=1./127.5,  # Normalize to range [0, 2]
    preprocessing_function=lambda x: x - 1  # Shift to range [-1, 1]
)

# %%
# Training set and validation set
train_generator = datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/train',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
validation_generator = validation_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/validation',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical'
)
test_generator = test_datagen.flow_from_directory(
    '/content/drive/MyDrive/Ear Disease/Split Dataset/test',
    target_size=(229, 229),
    batch_size=64,
    class_mode='categorical',
)
# Out:
# Found 836 images belonging to 20 classes.
# Found 214 images belonging to 20 classes.
# Found 233 images belonging to 20 classes.

# %%
# Load the Xception model
pre_trained_model = Xception(input_shape=(229, 229, 3), include_top=False, weights='imagenet')
for layer in pre_trained_model.layers:
    layer.trainable = False

# Define input
input_layer = Input(shape=(229, 229, 3))

# Build the model
x = pre_trained_model(input_layer)
x = GlobalAveragePooling2D()(x)
x = Dense(209, activation='relu')(x)
x = Dropout(0.2)(x)
output = Dense(20, activation='softmax')(x)

# Create the model
model = Model(inputs=input_layer, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 0s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 229, 229, 3)]     0
#
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 209)               428241
#
#  dropout (Dropout)           (None, 209)               0
#
#  dense_1 (Dense)             (None, 20)                4200
#
# =================================================================
# Total params: 21293921 (81.23 MB)
# Trainable params: 432441 (1.65 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
import tensorflow as tf

# Model Compile
OPT = tf.keras.optimizers.Adam(learning_rate=0.0018277161121728472)
METRIC = tf.keras.metrics.AUC(name='auc')

model.compile(loss='categorical_crossentropy',
              metrics=[METRIC],
              optimizer=OPT)

# %%
filepath = '/content/drive/MyDrive/Ear Disease/2_Visualisasi_Xception.keras'

checkpoint    = ModelCheckpoint(filepath,
                                monitor = 'val_auc',
                                mode='max',
                                save_best_only=True,
                                verbose = 1)


callback_list = [checkpoint]

# %%
model_history=model.fit(train_generator,
                        validation_data=validation_generator,
                        epochs = 100,

                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5432 - auc: 0.9927
# Epoch 1: val_auc did not improve from 0.92298
# 14/14 [==============================] - 26s 2s/step - loss: 0.5432 - auc: 0.9927 - val_loss: 1.7538 - val_auc: 0.9136
# Epoch 2/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6966 - auc: 0.9860
# Epoch 2: val_auc did not improve from 0.92298
# 14/14 [==============================] - 26s 2s/step - loss: 0.6966 - auc: 0.9860 - val_loss: 1.7920 - val_auc: 0.9050
# Epoch 3/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5640 - auc: 0.9927
# Epoch 3: val_auc did not improve from 0.92298
# 14/14 [==============================] - 26s 2s/step - loss: 0.5640 - auc: 0.9927 - val_loss: 1.7553 - val_auc: 0.9140
# Epoch 4/100
# 14/14 [==============================] - ETA: 0s - loss: 0.6184 - auc: 0.9901
# Epoch 4: val_auc improved from 0.92298 to 0.92403, saving model to /content/drive/MyDrive/Ear Disease/2_Visualisasi_Xception.keras
# 14/14 [==============================] - 27s 2s/step - loss: 0.6184 - auc: 0.9901 - val_loss: 1.6872 - val_auc: 0.9240
# Epoch 5/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5066 - auc: 0.9940
# Epoch 5: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.5066 - auc: 0.9940 - val_loss: 1.6953 - val_auc: 0.9196
# Epoch 6/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4785 - auc: 0.9946
# Epoch 6: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4785 - auc: 0.9946 - val_loss: 1.6994 - val_auc: 0.9172
# Epoch 7/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5374 - auc: 0.9925
# Epoch 7: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.5374 - auc: 0.9925 - val_loss: 1.7251 - val_auc: 0.9154
# Epoch 8/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4472 - auc: 0.9961
# Epoch 8: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4472 - auc: 0.9961 - val_loss: 1.7354 - val_auc: 0.9159
# Epoch 9/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4986 - auc: 0.9929
# Epoch 9: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4986 - auc: 0.9929 - val_loss: 1.7504 - val_auc: 0.9163
# Epoch 10/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4463 - auc: 0.9950
# Epoch 10: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4463 - auc: 0.9950 - val_loss: 1.7840 - val_auc: 0.9085
# Epoch 11/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5370 - auc: 0.9930
# Epoch 11: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.5370 - auc: 0.9930 - val_loss: 1.7687 - val_auc: 0.9118
# Epoch 12/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5209 - auc: 0.9932
# Epoch 12: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.5209 - auc: 0.9932 - val_loss: 1.8287 - val_auc: 0.9121
# Epoch 13/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5018 - auc: 0.9942
# Epoch 13: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.5018 - auc: 0.9942 - val_loss: 1.7808 - val_auc: 0.9144
# Epoch 14/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4015 - auc: 0.9953
# Epoch 14: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4015 - auc: 0.9953 - val_loss: 1.8385 - val_auc: 0.9049
# Epoch 15/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4473 - auc: 0.9951
# Epoch 15: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4473 - auc: 0.9951 - val_loss: 2.0146 - val_auc: 0.9017
# Epoch 16/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4455 - auc: 0.9947
# Epoch 16: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4455 - auc: 0.9947 - val_loss: 1.7992 - val_auc: 0.9088
# Epoch 17/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4126 - auc: 0.9954
# Epoch 17: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4126 - auc: 0.9954 - val_loss: 1.8010 - val_auc: 0.9100
# Epoch 18/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3589 - auc: 0.9972
# Epoch 18: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3589 - auc: 0.9972 - val_loss: 1.8016 - val_auc: 0.9148
# Epoch 19/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3878 - auc: 0.9959
# Epoch 19: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3878 - auc: 0.9959 - val_loss: 1.7677 - val_auc: 0.9173
# Epoch 20/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4262 - auc: 0.9945
# Epoch 20: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4262 - auc: 0.9945 - val_loss: 1.8177 - val_auc: 0.9116
# Epoch 21/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4884 - auc: 0.9922
# Epoch 21: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4884 - auc: 0.9922 - val_loss: 1.8044 - val_auc: 0.9129
# Epoch 22/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4737 - auc: 0.9945
# Epoch 22: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4737 - auc: 0.9945 - val_loss: 1.8804 - val_auc: 0.9034
# Epoch 23/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4659 - auc: 0.9943
# Epoch 23: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4659 - auc: 0.9943 - val_loss: 2.4343 - val_auc: 0.8650
# Epoch 24/100
# 14/14 [==============================] - ETA: 0s - loss: 0.5836 - auc: 0.9906
# Epoch 24: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.5836 - auc: 0.9906 - val_loss: 1.7774 - val_auc: 0.9088
# Epoch 25/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4360 - auc: 0.9954
# Epoch 25: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4360 - auc: 0.9954 - val_loss: 1.8555 - val_auc: 0.9070
# Epoch 26/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3560 - auc: 0.9972
# Epoch 26: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3560 - auc: 0.9972 - val_loss: 1.7811 - val_auc: 0.9114
# Epoch 27/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4248 - auc: 0.9945
# Epoch 27: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4248 - auc: 0.9945 - val_loss: 1.8353 - val_auc: 0.9011
# Epoch 28/100
# 14/14 [==============================] - ETA: 0s - loss: 0.4082 - auc: 0.9962
# Epoch 28: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.4082 - auc: 0.9962 - val_loss: 1.7606 - val_auc: 0.9201
# Epoch 29/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3889 - auc: 0.9965
# Epoch 29: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3889 - auc: 0.9965 - val_loss: 1.7706 - val_auc: 0.9153
# Epoch 30/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3567 - auc: 0.9970
# Epoch 30: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3567 - auc: 0.9970 - val_loss: 1.7813 - val_auc: 0.9105
# Epoch 31/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3597 - auc: 0.9962
# Epoch 31: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3597 - auc: 0.9962 - val_loss: 1.8148 - val_auc: 0.9107
# Epoch 32/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3784 - auc: 0.9967
# Epoch 32: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3784 - auc: 0.9967 - val_loss: 1.7764 - val_auc: 0.9142
# Epoch 33/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3380 - auc: 0.9973
# Epoch 33: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3380 - auc: 0.9973 - val_loss: 1.7977 - val_auc: 0.9085
# Epoch 34/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3941 - auc: 0.9957
# Epoch 34: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3941 - auc: 0.9957 - val_loss: 1.8721 - val_auc: 0.9073
# Epoch 35/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3732 - auc: 0.9966
# Epoch 35: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3732 - auc: 0.9966 - val_loss: 1.7457 - val_auc: 0.9196
# Epoch 36/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3491 - auc: 0.9969
# Epoch 36: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3491 - auc: 0.9969 - val_loss: 1.8248 - val_auc: 0.9151
# Epoch 37/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3568 - auc: 0.9970
# Epoch 37: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3568 - auc: 0.9970 - val_loss: 1.8024 - val_auc: 0.9088
# Epoch 38/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3041 - auc: 0.9979
# Epoch 38: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3041 - auc: 0.9979 - val_loss: 1.7706 - val_auc: 0.9147
# Epoch 39/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2972 - auc: 0.9980
# Epoch 39: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2972 - auc: 0.9980 - val_loss: 1.7953 - val_auc: 0.9143
# Epoch 40/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3807 - auc: 0.9964
# Epoch 40: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.3807 - auc: 0.9964 - val_loss: 1.8690 - val_auc: 0.9109
# Epoch 41/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3077 - auc: 0.9979
# Epoch 41: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.3077 - auc: 0.9979 - val_loss: 1.8421 - val_auc: 0.9063
# Epoch 42/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2875 - auc: 0.9982
# Epoch 42: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2875 - auc: 0.9982 - val_loss: 1.8248 - val_auc: 0.9219
# Epoch 43/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2971 - auc: 0.9978
# Epoch 43: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2971 - auc: 0.9978 - val_loss: 1.9829 - val_auc: 0.9073
# Epoch 44/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2633 - auc: 0.9983
# Epoch 44: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2633 - auc: 0.9983 - val_loss: 1.9095 - val_auc: 0.9110
# Epoch 45/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2402 - auc: 0.9987
# Epoch 45: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2402 - auc: 0.9987 - val_loss: 1.8439 - val_auc: 0.9077
# Epoch 46/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2330 - auc: 0.9988
# Epoch 46: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2330 - auc: 0.9988 - val_loss: 1.8789 - val_auc: 0.9086
# Epoch 47/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2518 - auc: 0.9986
# Epoch 47: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2518 - auc: 0.9986 - val_loss: 1.8581 - val_auc: 0.9122
# Epoch 48/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2707 - auc: 0.9976
# Epoch 48: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2707 - auc: 0.9976 - val_loss: 1.8816 - val_auc: 0.9116
# Epoch 49/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2807 - auc: 0.9975
# Epoch 49: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2807 - auc: 0.9975 - val_loss: 1.8783 - val_auc: 0.9025
# Epoch 50/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2744 - auc: 0.9977
# Epoch 50: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2744 - auc: 0.9977 - val_loss: 1.8902 - val_auc: 0.9048
# Epoch 51/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3221 - auc: 0.9969
# Epoch 51: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.3221 - auc: 0.9969 - val_loss: 1.9685 - val_auc: 0.9001
# Epoch 52/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2917 - auc: 0.9973
# Epoch 52: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2917 - auc: 0.9973 - val_loss: 1.8567 - val_auc: 0.9150
# Epoch 53/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2605 - auc: 0.9984
# Epoch 53: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2605 - auc: 0.9984 - val_loss: 1.8264 - val_auc: 0.9124
# Epoch 54/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2610 - auc: 0.9983
# Epoch 54: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2610 - auc: 0.9983 - val_loss: 1.7620 - val_auc: 0.9182
# Epoch 55/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2417 - auc: 0.9987
# Epoch 55: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2417 - auc: 0.9987 - val_loss: 1.7873 - val_auc: 0.9186
# Epoch 56/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2123 - auc: 0.9983
# Epoch 56: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2123 - auc: 0.9983 - val_loss: 1.8618 - val_auc: 0.9119
# Epoch 57/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1964 - auc: 0.9986
# Epoch 57: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1964 - auc: 0.9986 - val_loss: 1.7623 - val_auc: 0.9213
# Epoch 58/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2629 - auc: 0.9978
# Epoch 58: val_auc did not improve from 0.92403
# 14/14 [==============================] - 27s 2s/step - loss: 0.2629 - auc: 0.9978 - val_loss: 1.8719 - val_auc: 0.9123
# Epoch 59/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2237 - auc: 0.9988
# Epoch 59: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2237 - auc: 0.9988 - val_loss: 1.8173 - val_auc: 0.9121
# Epoch 60/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2242 - auc: 0.9982
# Epoch 60: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2242 - auc: 0.9982 - val_loss: 1.9377 - val_auc: 0.9113
# Epoch 61/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2405 - auc: 0.9988
# Epoch 61: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2405 - auc: 0.9988 - val_loss: 1.8154 - val_auc: 0.9173
# Epoch 62/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2438 - auc: 0.9988
# Epoch 62: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2438 - auc: 0.9988 - val_loss: 1.8499 - val_auc: 0.9122
# Epoch 63/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2409 - auc: 0.9986
# Epoch 63: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2409 - auc: 0.9986 - val_loss: 1.9762 - val_auc: 0.9061
# Epoch 64/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2163 - auc: 0.9989
# Epoch 64: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2163 - auc: 0.9989 - val_loss: 2.0486 - val_auc: 0.8940
# Epoch 65/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2422 - auc: 0.9986
# Epoch 65: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2422 - auc: 0.9986 - val_loss: 1.8817 - val_auc: 0.9114
# Epoch 66/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2334 - auc: 0.9981
# Epoch 66: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2334 - auc: 0.9981 - val_loss: 1.9188 - val_auc: 0.9059
# Epoch 67/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2344 - auc: 0.9981
# Epoch 67: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2344 - auc: 0.9981 - val_loss: 1.8909 - val_auc: 0.9040
# Epoch 68/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2265 - auc: 0.9982
# Epoch 68: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2265 - auc: 0.9982 - val_loss: 1.7935 - val_auc: 0.9100
# Epoch 69/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2311 - auc: 0.9988
# Epoch 69: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2311 - auc: 0.9988 - val_loss: 1.8180 - val_auc: 0.9118
# Epoch 70/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1871 - auc: 0.9993
# Epoch 70: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1871 - auc: 0.9993 - val_loss: 1.8819 - val_auc: 0.9109
# Epoch 71/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2318 - auc: 0.9987
# Epoch 71: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2318 - auc: 0.9987 - val_loss: 1.9996 - val_auc: 0.8940
# Epoch 72/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2147 - auc: 0.9989
# Epoch 72: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2147 - auc: 0.9989 - val_loss: 1.9461 - val_auc: 0.9077
# Epoch 73/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2075 - auc: 0.9991
# Epoch 73: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2075 - auc: 0.9991 - val_loss: 1.8857 - val_auc: 0.9093
# Epoch 74/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2230 - auc: 0.9988
# Epoch 74: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2230 - auc: 0.9988 - val_loss: 1.9082 - val_auc: 0.9096
# Epoch 75/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2101 - auc: 0.9984
# Epoch 75: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2101 - auc: 0.9984 - val_loss: 1.8230 - val_auc: 0.9100
# Epoch 76/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2146 - auc: 0.9989
# Epoch 76: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2146 - auc: 0.9989 - val_loss: 1.8773 - val_auc: 0.9049
# Epoch 77/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2293 - auc: 0.9981
# Epoch 77: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2293 - auc: 0.9981 - val_loss: 1.8689 - val_auc: 0.9114
# Epoch 78/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2133 - auc: 0.9989
# Epoch 78: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2133 - auc: 0.9989 - val_loss: 1.8599 - val_auc: 0.9123
# Epoch 79/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1893 - auc: 0.9986
# Epoch 79: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1893 - auc: 0.9986 - val_loss: 1.9052 - val_auc: 0.9142
# Epoch 80/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1840 - auc: 0.9992
# Epoch 80: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1840 - auc: 0.9992 - val_loss: 2.0078 - val_auc: 0.9026
# Epoch 81/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1800 - auc: 0.9993
# Epoch 81: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1800 - auc: 0.9993 - val_loss: 2.0202 - val_auc: 0.9019
# Epoch 82/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2281 - auc: 0.9981
# Epoch 82: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2281 - auc: 0.9981 - val_loss: 2.0447 - val_auc: 0.8932
# Epoch 83/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2938 - auc: 0.9960
# Epoch 83: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2938 - auc: 0.9960 - val_loss: 2.1180 - val_auc: 0.8937
# Epoch 84/100
# 14/14 [==============================] - ETA: 0s - loss: 0.3086 - auc: 0.9975
# Epoch 84: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.3086 - auc: 0.9975 - val_loss: 1.8371 - val_auc: 0.9108
# Epoch 85/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2830 - auc: 0.9979
# Epoch 85: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2830 - auc: 0.9979 - val_loss: 1.9102 - val_auc: 0.9063
# Epoch 86/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2511 - auc: 0.9978
# Epoch 86: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2511 - auc: 0.9978 - val_loss: 1.8791 - val_auc: 0.9091
# Epoch 87/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2333 - auc: 0.9988
# Epoch 87: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2333 - auc: 0.9988 - val_loss: 1.9117 - val_auc: 0.9050
# Epoch 88/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2165 - auc: 0.9988
# Epoch 88: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2165 - auc: 0.9988 - val_loss: 1.8657 - val_auc: 0.9063
# Epoch 89/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1957 - auc: 0.9985
# Epoch 89: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1957 - auc: 0.9985 - val_loss: 2.0941 - val_auc: 0.9000
# Epoch 90/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2240 - auc: 0.9981
# Epoch 90: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2240 - auc: 0.9981 - val_loss: 1.8765 - val_auc: 0.9073
# Epoch 91/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1713 - auc: 0.9993
# Epoch 91: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1713 - auc: 0.9993 - val_loss: 1.9221 - val_auc: 0.9072
# Epoch 92/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1662 - auc: 0.9993
# Epoch 92: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1662 - auc: 0.9993 - val_loss: 1.9638 - val_auc: 0.9035
# Epoch 93/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1716 - auc: 0.9994
# Epoch 93: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1716 - auc: 0.9994 - val_loss: 1.9159 - val_auc: 0.9046
# Epoch 94/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1999 - auc: 0.9990
# Epoch 94: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1999 - auc: 0.9990 - val_loss: 1.8299 - val_auc: 0.9134
# Epoch 95/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2040 - auc: 0.9983
# Epoch 95: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2040 - auc: 0.9983 - val_loss: 1.8637 - val_auc: 0.9170
# Epoch 96/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1722 - auc: 0.9993
# Epoch 96: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1722 - auc: 0.9993 - val_loss: 1.8982 - val_auc: 0.9095
# Epoch 97/100
# 14/14 [==============================] - ETA: 0s - loss: 0.1421 - auc: 0.9996
# Epoch 97: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.1421 - auc: 0.9996 - val_loss: 1.9979 - val_auc: 0.8970
# Epoch 98/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2200 - auc: 0.9988
# Epoch 98: val_auc did not improve from 0.92403
# 14/14 [==============================] - 25s 2s/step - loss: 0.2200 - auc: 0.9988 - val_loss: 1.9971 - val_auc: 0.9018
# Epoch 99/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2171 - auc: 0.9982
# Epoch 99: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2171 - auc: 0.9982 - val_loss: 1.9646 - val_auc: 0.9047
# Epoch 100/100
# 14/14 [==============================] - ETA: 0s - loss: 0.2949 - auc: 0.9960
# Epoch 100: val_auc did not improve from 0.92403
# 14/14 [==============================] - 26s 2s/step - loss: 0.2949 - auc: 0.9960 - val_loss: 1.8668 - val_auc: 0.9109

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['auc', 'loss']):
    ax[i].plot(model_history.history[met])
    ax[i].plot(model_history.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
model.evaluate(test_generator)
# Out:
# 4/4 [==============================] - 45s 15s/step - loss: 2.4111 - auc: 0.8608
# [2.4111249446868896, 0.8608044981956482]

# %%
from tensorflow.keras.models import load_model
# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/2_Visualisasi_Xception.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes
# Out:
# 4/4 [==============================] - 5s 912ms/step

# %%
from sklearn.metrics import roc_auc_score

# Compute AUC
auc = roc_auc_score(y_true, y_pred, multi_class='ovo')
print(f'AUC on the test set: {auc}')
# Out:
# AUC on the test set: 0.4787011375944424

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/2_Visualisasi_Xception.keras')

# Make predictions on the test set
y_pred = model.predict(test_generator)

# Extract true labels from the generator
y_true = test_generator.classes

# Convert predictions to class labels
y_pred_classes = np.argmax(y_pred, axis=1)

# Calculate the confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal', 'Miringitis Bulosa', 'Normal', 'OE Difusa', 'OE Furunkulosa',
    'OMA Hiperemis', 'OMA Oklusi Tuba', 'OMA Perforasi', 'OMA Resolusi', 'OMA Supurasi', 'OM Efusi', 'OMSK Resolusi', 'OMSK Tipe Aman',
    'OMSK Tipe Bahaya', 'Otomikosis', 'Perforasi M T', 'Tympanosklerotik'
]

# Plot the confusion matrix using seaborn for better visualization
plt.figure(figsize=(14, 12))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 4/4 [==============================] - 5s 963ms/step

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

# Load your trained CNN model
model = load_model('/content/drive/MyDrive/Ear Disease/2_Visualisasi_Xception.keras')

# Define the class names
class_names = [
    'Aerotitis Barotrauma', 'Cerumen', 'Corpus Alienum', 'M T Normal',
    'Miringitis Bulosa', 'Normal', 'Otomikosis', 'OE Difusa',
    'OE Furunkulosa', 'OMA Hiperemis',
    'OMA Oklusi Tuba', 'OMA Perforasi',
    'OMA Resolusi', 'OMA Supurasi',
    'OM Efusi', 'OMSK Resolusi',
    'OMSK Tipe Aman', 'OMSK Tipe Bahaya',
    'Perforasi M T', 'Tympanosklerotik'
]

def load_and_preprocess_image(img_path, target_size=(224, 224)):
    # Load the image
    img = image.load_img(img_path, target_size=target_size)
    # Convert the image to array
    img_array = image.img_to_array(img)
    # Expand dimensions to match the model input
    img_array = np.expand_dims(img_array, axis=0)
    # Normalize the image
    img_array = img_array / 255.0
    return img_array

def predict_image(img_path):
    # Preprocess the image
    img_array = load_and_preprocess_image(img_path)
    # Make prediction
    predictions = model.predict(img_array)
    # Get the class with highest probability
    predicted_class = np.argmax(predictions, axis=1)
    # Get the class name
    predicted_class_name = class_names[predicted_class[0]]

    # Plot the image with prediction
    img = image.load_img(img_path, target_size=(224, 224))
    plt.imshow(img)
    plt.title(f'Predicted: {predicted_class_name}')
    plt.axis('off')
    plt.show()

    return predicted_class_name

# Test the function with an image path
img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
predicted_class_name = predict_image(img_path)
print(f'The model predicts: {predicted_class_name}')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d37865027173> in <cell line: 53>()
#      51 # Test the function with an image path
#      52 img_path = '/content/drive/MyDrive/Ear Disease/Split Dataset/test/M Timpani normal/2019-08-20T19-48-12.jpg'
# ---> 53 predicted_class_name = predict_image(img_path)
#      54 print(f'The model predicts: {predicted_class_name}')
#
# <ipython-input-16-d37865027173> in predict_image(img_path)
#      34     img_array = load_and_preprocess_image(img_path)
#      35     # Make prediction
# ---> 36     predictions = model.predict(img_array)
#      37     # Get the class with highest probability
#      38     predicted_class = np.argmax(predictions, axis=1)
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     243                 if spec_dim is not None and dim is not None:
#     244                     if spec_dim != dim:
# --> 245                         raise ValueError(
#     246                             f'Input {input_index} of layer "{layer_name}" is '
#     247                             "incompatible with the layer: "
#
# ValueError: Input 0 of layer "functional" is incompatible with the layer: expected shape=(None, 229, 229, 3), found shape=(1, 224, 224, 3)
